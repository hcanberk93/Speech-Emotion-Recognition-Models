# %%
# Importing required libraries 
import re
import sklearn, h5py
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold

import numpy as np
from numpy import savetxt
from numpy.fft import ifft,ifft2

import matplotlib.pyplot as plt
from matplotlib.pyplot import specgram
import tensorflow as tf
#from tensorflow import keras
#from tensorflow.python.keras import backend
#from tensorflow.python.keras.callbacks import TensorBoard, ModelCheckpoint
import os
from time import time
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sn

import keras
from keras import regularizers
from keras import backend
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential, Model, model_from_json
from keras.layers import Dense, Embedding, LSTM
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Conv1D,Conv2D, MaxPooling1D, AveragePooling1D
from keras.utils import np_utils, to_categorical
from keras.callbacks import ModelCheckpoint, TensorBoard

# Other  
import librosa
import librosa.display

from scipy.io import wavfile
from scipy import signal
from scipy.fft import fft, fftfreq

import glob 
import os
import pickle
import IPython.display as ipd  # To play sound in the notebook

import pickle
# ignore warnings 
import sys
import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
global sampleRate,HOP,HOP_LENGTH,LABELS,MFCC;
sampleRate =48000;
ravdessPath ='/home/czerwone/Desktop/Datasets/Ravdess/';
iemocapPath ='/home/czerwone/Desktop/Datasets/IEMOCAP/Data/Impro';
iemocapLabelPath ='/home/czerwone/Desktop/Datasets/IEMOCAP/Labels';

LABELS = {1:"Neutral", 2:"Calm", 3:"Happy", 4:"Sad", 5:"Angry", 6:"Fearful", 7:"Disgust", 8:"Surprised"};

fileList = getListOfFiles(ravdessPath)
iemocapFiles = getListOfFiles(iemocapPath)



lengthValsRavdess= getDatasetStats(ravdessPath);
#lengthValsIemocap= getDatasetStats(iemocapPath);
# Out:
# 1354
# 1129

# %%
signal,_ = librosa.load(fileList[0], res_type='kaiser_best',sr=sampleRate);
signalTest,_ = librosa.effects.trim(signal);
print(len(signal))
print(len(signalTest))
# Out:
# 158558
# 101888

# %%
X = getSpectograms(fileList)
Y = np.array(classifyData(ravdessPath));

# %%
X_Norm = dataNormalization(X)

# %%
cnnInst = cnn(Y[:,0]-1,X_Norm[..., np.newaxis],0.2)
cnnInst.split_train_test()
cnnInst.build_model()
# Out:
# built cnn model..
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 64, 64, 16)        800
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 30, 30, 32)        12832
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 15, 15, 32)        9248
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 7, 7, 64)          18496
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 3, 3, 64)          36928
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 2, 2, 128)         73856
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 1, 128)         147584
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               66048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 4104
# =================================================================
# Total params: 369,896
# Trainable params: 369,896
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = cnnInst.train();
# Out:
# training model
# Epoch 1/50
# 9/9 [==============================] - 4s 347ms/step - loss: 2.0733 - accuracy: 0.1387 - val_loss: 2.0409 - val_accuracy: 0.1562
#
# Epoch 00001: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 2/50
# 9/9 [==============================] - 3s 290ms/step - loss: 2.0081 - accuracy: 0.2277 - val_loss: 1.9195 - val_accuracy: 0.1979
#
# Epoch 00002: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 3/50
# 9/9 [==============================] - 2s 268ms/step - loss: 1.8602 - accuracy: 0.2685 - val_loss: 1.8687 - val_accuracy: 0.2639
#
# Epoch 00003: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 4/50
# 9/9 [==============================] - 3s 318ms/step - loss: 1.7299 - accuracy: 0.2992 - val_loss: 1.7079 - val_accuracy: 0.3507
#
# Epoch 00004: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 5/50
# 9/9 [==============================] - 3s 292ms/step - loss: 1.5850 - accuracy: 0.3855 - val_loss: 1.7795 - val_accuracy: 0.2986
#
# Epoch 00005: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 6/50
# 9/9 [==============================] - 3s 282ms/step - loss: 1.5242 - accuracy: 0.3792 - val_loss: 1.5980 - val_accuracy: 0.3646
#
# Epoch 00006: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 7/50
# 9/9 [==============================] - 2s 265ms/step - loss: 1.4116 - accuracy: 0.4593 - val_loss: 1.5341 - val_accuracy: 0.3715
#
# Epoch 00007: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 8/50
# 9/9 [==============================] - 3s 320ms/step - loss: 1.3288 - accuracy: 0.4947 - val_loss: 1.5351 - val_accuracy: 0.4062
#
# Epoch 00008: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 9/50
# 9/9 [==============================] - 3s 317ms/step - loss: 1.3190 - accuracy: 0.4828 - val_loss: 1.4901 - val_accuracy: 0.4375
#
# Epoch 00009: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 10/50
# 9/9 [==============================] - 3s 290ms/step - loss: 1.2271 - accuracy: 0.5362 - val_loss: 1.4377 - val_accuracy: 0.4896
#
# Epoch 00010: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 11/50
# 9/9 [==============================] - 3s 299ms/step - loss: 1.0832 - accuracy: 0.5945 - val_loss: 1.4923 - val_accuracy: 0.5069
#
# Epoch 00011: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 12/50
# 9/9 [==============================] - 3s 293ms/step - loss: 1.0265 - accuracy: 0.5980 - val_loss: 1.4219 - val_accuracy: 0.5035
#
# Epoch 00012: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 13/50
# 9/9 [==============================] - 3s 315ms/step - loss: 0.9674 - accuracy: 0.6183 - val_loss: 1.2649 - val_accuracy: 0.5347
#
# Epoch 00013: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 14/50
# 9/9 [==============================] - 3s 293ms/step - loss: 0.8858 - accuracy: 0.6757 - val_loss: 1.3913 - val_accuracy: 0.5278
#
# Epoch 00014: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 15/50
# 9/9 [==============================] - 3s 311ms/step - loss: 0.8179 - accuracy: 0.6870 - val_loss: 1.3403 - val_accuracy: 0.5035
#
# Epoch 00015: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 16/50
# 9/9 [==============================] - 3s 291ms/step - loss: 0.7605 - accuracy: 0.7184 - val_loss: 1.3720 - val_accuracy: 0.5069
#
# Epoch 00016: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 17/50
# 9/9 [==============================] - 3s 290ms/step - loss: 0.6544 - accuracy: 0.7751 - val_loss: 1.4018 - val_accuracy: 0.5382
#
# Epoch 00017: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 18/50
# 9/9 [==============================] - 3s 292ms/step - loss: 0.5909 - accuracy: 0.7752 - val_loss: 1.3685 - val_accuracy: 0.5417
#
# Epoch 00018: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 19/50
# 9/9 [==============================] - 3s 306ms/step - loss: 0.4949 - accuracy: 0.8162 - val_loss: 1.3900 - val_accuracy: 0.5625
#
# Epoch 00019: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 20/50
# 9/9 [==============================] - 2s 276ms/step - loss: 0.4174 - accuracy: 0.8364 - val_loss: 1.4855 - val_accuracy: 0.5694
#
# Epoch 00020: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 21/50
# 9/9 [==============================] - 3s 287ms/step - loss: 0.2902 - accuracy: 0.8971 - val_loss: 1.5256 - val_accuracy: 0.5521
#
# Epoch 00021: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 22/50
# 9/9 [==============================] - 3s 289ms/step - loss: 0.3166 - accuracy: 0.8767 - val_loss: 1.6970 - val_accuracy: 0.5799
#
# Epoch 00022: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 23/50
# 9/9 [==============================] - 3s 292ms/step - loss: 0.3147 - accuracy: 0.8936 - val_loss: 1.5023 - val_accuracy: 0.6181
#
# Epoch 00023: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 24/50
# 9/9 [==============================] - 3s 315ms/step - loss: 0.2717 - accuracy: 0.9069 - val_loss: 1.5566 - val_accuracy: 0.6285
#
# Epoch 00024: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 25/50
# 9/9 [==============================] - 3s 292ms/step - loss: 0.2349 - accuracy: 0.9126 - val_loss: 1.6456 - val_accuracy: 0.6042
#
# Epoch 00025: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 26/50
# 9/9 [==============================] - 3s 285ms/step - loss: 0.2251 - accuracy: 0.9194 - val_loss: 1.8250 - val_accuracy: 0.5903
#
# Epoch 00026: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 27/50
# 9/9 [==============================] - 3s 313ms/step - loss: 0.1739 - accuracy: 0.9365 - val_loss: 1.7569 - val_accuracy: 0.6111
#
# Epoch 00027: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 28/50
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0784 - accuracy: 0.9803 - val_loss: 1.9545 - val_accuracy: 0.6111
#
# Epoch 00028: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 29/50
# 9/9 [==============================] - 3s 287ms/step - loss: 0.0751 - accuracy: 0.9711 - val_loss: 2.1749 - val_accuracy: 0.6111
#
# Epoch 00029: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 30/50
# 9/9 [==============================] - 3s 291ms/step - loss: 0.0506 - accuracy: 0.9923 - val_loss: 2.0179 - val_accuracy: 0.6562
# Epoch 00030: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 31/50
# 9/9 [==============================] - 3s 296ms/step - loss: 0.0697 - accuracy: 0.9777 - val_loss: 2.4196 - val_accuracy: 0.5938
#
# Epoch 00031: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 32/50
# 9/9 [==============================] - 3s 313ms/step - loss: 0.0934 - accuracy: 0.9676 - val_loss: 1.9260 - val_accuracy: 0.6354
#
# Epoch 00032: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 33/50
# 9/9 [==============================] - 3s 284ms/step - loss: 0.0778 - accuracy: 0.9679 - val_loss: 2.2296 - val_accuracy: 0.5799
#
# Epoch 00033: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 34/50
# 9/9 [==============================] - 2s 266ms/step - loss: 0.0996 - accuracy: 0.9657 - val_loss: 1.8179 - val_accuracy: 0.6389
#
# Epoch 00034: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 35/50
# 9/9 [==============================] - 2s 267ms/step - loss: 0.0578 - accuracy: 0.9847 - val_loss: 1.9464 - val_accuracy: 0.6562
#
# Epoch 00035: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 36/50
# 9/9 [==============================] - 3s 294ms/step - loss: 0.0557 - accuracy: 0.9856 - val_loss: 2.4719 - val_accuracy: 0.5903
#
# Epoch 00036: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 37/50
# 9/9 [==============================] - 2s 278ms/step - loss: 0.0581 - accuracy: 0.9781 - val_loss: 2.0006 - val_accuracy: 0.6076
#
# Epoch 00037: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 38/50
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0319 - accuracy: 0.9904 - val_loss: 2.2008 - val_accuracy: 0.6562
#
# Epoch 00038: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 39/50
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0323 - accuracy: 0.9901 - val_loss: 2.1928 - val_accuracy: 0.6458
#
# Epoch 00039: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 40/50
# 9/9 [==============================] - 3s 315ms/step - loss: 0.0698 - accuracy: 0.9735 - val_loss: 2.3688 - val_accuracy: 0.6493
#
# Epoch 00040: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 41/50
# 9/9 [==============================] - 3s 304ms/step - loss: 0.0637 - accuracy: 0.9741 - val_loss: 2.1096 - val_accuracy: 0.5868
#
# Epoch 00041: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 42/50
# 9/9 [==============================] - 3s 313ms/step - loss: 0.0634 - accuracy: 0.9806 - val_loss: 2.0371 - val_accuracy: 0.6528
#
# Epoch 00042: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 43/50
# 9/9 [==============================] - 3s 300ms/step - loss: 0.0287 - accuracy: 0.9879 - val_loss: 2.0681 - val_accuracy: 0.6319
#
# Epoch 00043: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 44/50
# 9/9 [==============================] - 3s 293ms/step - loss: 0.0426 - accuracy: 0.9863 - val_loss: 2.4802 - val_accuracy: 0.6146
#
# Epoch 00044: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 45/50
# 9/9 [==============================] - 3s 318ms/step - loss: 0.0499 - accuracy: 0.9814 - val_loss: 2.1899 - val_accuracy: 0.6424
#
# Epoch 00045: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 46/50
# 9/9 [==============================] - 3s 307ms/step - loss: 0.0828 - accuracy: 0.9752 - val_loss: 2.5807 - val_accuracy: 0.5694
#
# Epoch 00046: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 47/50
# 9/9 [==============================] - 3s 301ms/step - loss: 0.1186 - accuracy: 0.9637 - val_loss: 1.9055 - val_accuracy: 0.6389
#
# Epoch 00047: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 48/50
# 9/9 [==============================] - 3s 298ms/step - loss: 0.0849 - accuracy: 0.9751 - val_loss: 1.8877 - val_accuracy: 0.6562
#
# Epoch 00048: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 49/50
# 9/9 [==============================] - 2s 283ms/step - loss: 0.0557 - accuracy: 0.9851 - val_loss: 1.9779 - val_accuracy: 0.6424
#
# Epoch 00049: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 50/50
# 9/9 [==============================] - 3s 300ms/step - loss: 0.0276 - accuracy: 0.9932 - val_loss: 2.1585 - val_accuracy: 0.6354
#
# Epoch 00050: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5

# %%
cnnInst.evaluate();
# Out:
# 9/9 [==============================] - 0s 22ms/step - loss: 2.1585 - accuracy: 0.6354
# Test loss: 2.158463478088379
# Test accuracy: 0.6354166865348816
# (288,) (288,)
#               precision    recall  f1-score   support
#
#            0       0.34      0.88      0.49        17
#            1       0.81      0.54      0.65        39
#            2       0.67      0.62      0.64        26
#            3       0.56      0.40      0.46        48
#            4       0.84      0.74      0.79        35
#            5       0.71      0.77      0.74        44
#            6       0.72      0.71      0.72        41
#            7       0.56      0.61      0.58        38
#
#     accuracy                           0.64       288
#    macro avg       0.65      0.66      0.63       288
# weighted avg       0.67      0.64      0.64       288
#
# [[15  1  0  0  0  1  0  0]
#  [11 21  1  2  0  0  2  2]
#  [ 2  0 16  1  0  2  1  4]
#  [13  1  2 19  1  3  3  6]
#  [ 0  0  2  1 26  2  4  0]
#  [ 0  3  0  3  2 34  0  2]
#  [ 1  0  0  6  1  0 29  4]
#  [ 2  0  3  2  1  6  1 23]]

# %%
cnnInst.printHistory(history)

# %%
Y_Iemo=classifyData(iemocapPath,False)
# Script Emotions
# Neu - 609 Hap - 311 Sad - 476  Ang - 814
# Impro Emotions
# Neu - 1099 Hap - 284 Sad - 608  Ang - 289

# %%
iemocapLabelArray = ['neu','hap','sad','ang']
fList,Y = iemocapGetUsedAttributes(iemocapFiles,Y_Iemo,iemocapLabelArray)

# %%
X_Iemo=getSpectograms(fList)

# %%
X_Iemo_Norm = dataNormalization(X_Iemo)

# %%
cnnIemo = cnn(Y-1,X_Iemo_Norm[..., np.newaxis],0.2,4)
cnnIemo.split_train_test()
cnnIemo.build_model()
# Out:
# built cnn model..
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_246 (Conv2D)          (None, 64, 64, 16)        800
# _________________________________________________________________
# conv2d_247 (Conv2D)          (None, 30, 30, 32)        12832
# _________________________________________________________________
# conv2d_248 (Conv2D)          (None, 15, 15, 32)        9248
# _________________________________________________________________
# conv2d_249 (Conv2D)          (None, 7, 7, 64)          18496
# _________________________________________________________________
# conv2d_250 (Conv2D)          (None, 3, 3, 64)          36928
# _________________________________________________________________
# conv2d_251 (Conv2D)          (None, 2, 2, 128)         73856
# _________________________________________________________________
# conv2d_252 (Conv2D)          (None, 1, 1, 128)         147584
# _________________________________________________________________
# flatten_36 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_71 (Dense)             (None, 512)               66048
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_72 (Dense)             (None, 4)                 2052
# =================================================================
# Total params: 367,844
# Trainable params: 367,844
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
historyIemo = cnnIemo.train();
# Out:
# training model
# Train on 1768 samples, validate on 442 samples
# Epoch 1/50
# 1768/1768 [==============================] - 7s 4ms/step - loss: 1.3426 - accuracy: 0.3456 - val_loss: 1.2660 - val_accuracy: 0.3959
#
# Epoch 00001: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 2/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 1.2631 - accuracy: 0.4135 - val_loss: 1.1543 - val_accuracy: 0.4910
#
# Epoch 00002: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 3/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 1.1046 - accuracy: 0.5085 - val_loss: 1.0425 - val_accuracy: 0.5611
#
# Epoch 00003: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 4/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 1.0695 - accuracy: 0.5170 - val_loss: 1.0053 - val_accuracy: 0.6154
#
# Epoch 00004: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 5/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 1.0210 - accuracy: 0.5503 - val_loss: 0.9850 - val_accuracy: 0.6176
#
# Epoch 00005: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 6/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.9987 - accuracy: 0.5707 - val_loss: 1.0026 - val_accuracy: 0.5769
#
# Epoch 00006: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 7/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.9949 - accuracy: 0.5588 - val_loss: 0.9785 - val_accuracy: 0.6222
#
# Epoch 00007: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 8/50
# 1768/1768 [==============================] - 6s 3ms/step - loss: 0.9743 - accuracy: 0.5764 - val_loss: 0.9443 - val_accuracy: 0.6267
#
# Epoch 00008: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 9/50
# 1768/1768 [==============================] - 6s 3ms/step - loss: 0.9687 - accuracy: 0.5798 - val_loss: 0.9790 - val_accuracy: 0.5814
#
# Epoch 00009: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 10/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.9316 - accuracy: 0.6075 - val_loss: 0.9466 - val_accuracy: 0.6244
#
# Epoch 00010: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 11/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.8989 - accuracy: 0.6097 - val_loss: 0.9571 - val_accuracy: 0.6312
#
# Epoch 00011: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 12/50
# 1768/1768 [==============================] - 6s 3ms/step - loss: 0.8515 - accuracy: 0.6256 - val_loss: 0.9444 - val_accuracy: 0.6448
#
# Epoch 00012: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 13/50
# 1768/1768 [==============================] - 6s 3ms/step - loss: 0.8137 - accuracy: 0.6544 - val_loss: 0.9698 - val_accuracy: 0.6086
#
# Epoch 00013: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 14/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.7641 - accuracy: 0.6804 - val_loss: 1.0352 - val_accuracy: 0.5769
#
# Epoch 00014: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 15/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.7148 - accuracy: 0.7025 - val_loss: 1.0806 - val_accuracy: 0.5814
#
# Epoch 00015: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 16/50
# 1768/1768 [==============================] - 6s 3ms/step - loss: 0.6437 - accuracy: 0.7398 - val_loss: 1.1787 - val_accuracy: 0.5950
#
# Epoch 00016: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 17/50
# 1768/1768 [==============================] - 6s 3ms/step - loss: 0.5544 - accuracy: 0.7738 - val_loss: 1.3957 - val_accuracy: 0.5452
#
# Epoch 00017: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 18/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.4574 - accuracy: 0.8230 - val_loss: 1.5826 - val_accuracy: 0.5701
#
# Epoch 00018: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 19/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.3853 - accuracy: 0.8563 - val_loss: 1.6128 - val_accuracy: 0.5814
#
# Epoch 00019: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 20/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.3289 - accuracy: 0.8767 - val_loss: 1.8866 - val_accuracy: 0.5792
#
# Epoch 00020: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 21/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.3629 - accuracy: 0.8660 - val_loss: 1.7585 - val_accuracy: 0.5814
#
# Epoch 00021: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 22/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.2828 - accuracy: 0.9010 - val_loss: 1.8394 - val_accuracy: 0.5498
#
# Epoch 00022: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 23/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.2015 - accuracy: 0.9321 - val_loss: 2.0882 - val_accuracy: 0.5837
#
# Epoch 00023: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 24/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.1313 - accuracy: 0.9531 - val_loss: 3.0294 - val_accuracy: 0.5973
#
# Epoch 00024: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 25/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.1890 - accuracy: 0.9406 - val_loss: 2.0422 - val_accuracy: 0.5430
#
# Epoch 00025: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 26/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.1511 - accuracy: 0.9525 - val_loss: 2.0767 - val_accuracy: 0.5679
#
# Epoch 00026: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 27/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.1014 - accuracy: 0.9672 - val_loss: 2.6601 - val_accuracy: 0.5656
#
# Epoch 00027: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 28/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0852 - accuracy: 0.9695 - val_loss: 2.9360 - val_accuracy: 0.5633
#
# Epoch 00028: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 29/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0849 - accuracy: 0.9689 - val_loss: 2.8050 - val_accuracy: 0.5928
#
# Epoch 00029: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 30/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0527 - accuracy: 0.9808 - val_loss: 2.6506 - val_accuracy: 0.5747
#
# Epoch 00030: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 31/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0557 - accuracy: 0.9819 - val_loss: 2.9852 - val_accuracy: 0.5566
#
# Epoch 00031: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 32/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0364 - accuracy: 0.9893 - val_loss: 3.0951 - val_accuracy: 0.5814
#
# Epoch 00032: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 33/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0268 - accuracy: 0.9949 - val_loss: 3.2551 - val_accuracy: 0.5928
#
# Epoch 00033: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 34/50
# 1768/1768 [==============================] - 6s 3ms/step - loss: 0.0168 - accuracy: 0.9949 - val_loss: 3.4884 - val_accuracy: 0.5430
#
# Epoch 00034: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 35/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0115 - accuracy: 0.9972 - val_loss: 3.5079 - val_accuracy: 0.5543
#
# Epoch 00035: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 36/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0215 - accuracy: 0.9910 - val_loss: 3.3536 - val_accuracy: 0.5860
#
# Epoch 00036: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 37/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0130 - accuracy: 0.9966 - val_loss: 3.6322 - val_accuracy: 0.5724
#
# Epoch 00037: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 38/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0078 - accuracy: 0.9983 - val_loss: 3.7792 - val_accuracy: 0.5679
#
# Epoch 00038: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 39/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 3.8387 - val_accuracy: 0.5882
#
# Epoch 00039: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 40/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0047 - accuracy: 0.9994 - val_loss: 4.0833 - val_accuracy: 0.5701
#
# Epoch 00040: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 41/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0065 - accuracy: 0.9989 - val_loss: 3.9954 - val_accuracy: 0.6063
#
# Epoch 00041: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 42/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0048 - accuracy: 0.9989 - val_loss: 4.1272 - val_accuracy: 0.5814
#
# Epoch 00042: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 43/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 4.3917 - val_accuracy: 0.5724
#
# Epoch 00043: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 44/50
# 1768/1768 [==============================] - 6s 3ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 4.3731 - val_accuracy: 0.5928
#
# Epoch 00044: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 45/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0051 - accuracy: 0.9977 - val_loss: 4.4996 - val_accuracy: 0.5769
#
# Epoch 00045: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 46/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0236 - accuracy: 0.9921 - val_loss: 3.6854 - val_accuracy: 0.5747
#
# Epoch 00046: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 47/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0582 - accuracy: 0.9847 - val_loss: 3.3534 - val_accuracy: 0.5860
#
# Epoch 00047: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 48/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0864 - accuracy: 0.9745 - val_loss: 2.6873 - val_accuracy: 0.5656
#
# Epoch 00048: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 49/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0608 - accuracy: 0.9796 - val_loss: 2.5761 - val_accuracy: 0.5905
#
# Epoch 00049: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 50/50
# 1768/1768 [==============================] - 5s 3ms/step - loss: 0.0334 - accuracy: 0.9915 - val_loss: 2.8755 - val_accuracy: 0.5882
#
# Epoch 00050: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5

# %%
cnnIemo.evaluate();
# Out:
# 442/442 [==============================] - 0s 566us/step
# Test loss: 2.8754982667810776
# Test accuracy: 0.5882353186607361
# (442,) (442,)
#               precision    recall  f1-score   support
#
#            0       0.51      0.53      0.52       129
#            1       0.29      0.26      0.27        46
#            2       0.57      0.41      0.48        92
#            3       0.71      0.81      0.75       175
#
#     accuracy                           0.59       442
#    macro avg       0.52      0.50      0.51       442
# weighted avg       0.58      0.59      0.58       442
#
# [[ 69  13  19  28]
#  [ 14  12   7  13]
#  [ 27  10  38  17]
#  [ 24   7   3 141]]

# %%
cnnIemo.printHistory(historyIemo)

# %%
ravdessLabelArray =[1,3,4,5]
newFileList = ravdessGetUsedOnlyData(fileList,[1,3,4,5])

X_Rav = getSpectograms(newFileList)
Y_Rav = np.array(classifyData(ravdessPath,True,newFileList))[:,0]

#Converting Ravdess into IEMOCAP Labeling
Y_Rav = Y_Rav-1
Y_Rav[Y_Rav==0]=1


Y_Iemo=classifyData(iemocapPath,False)
iemocapLabelArray = ['neu','hap','sad','ang']
fList,Y_Iemo = iemocapGetUsedAttributes(iemocapFiles,Y_Iemo,iemocapLabelArray)
X_Iemo=getSpectograms(fList)

# %%
Y_Both = np.concatenate((Y_Rav,Y_Iemo),axis=0)
X_Both = np.concatenate((X_Rav,X_Iemo),axis=0)

# %%
X_Both_Norm = dataNormalization(X_Both)

# %%
cnnBoth = cnn(Y_Both-1,X_Both_Norm[..., np.newaxis],0.2,4)
cnnBoth.split_train_test()
cnnBoth.build_model()
# Out:
# built cnn model..
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_260 (Conv2D)          (None, 64, 64, 16)        800
# _________________________________________________________________
# conv2d_261 (Conv2D)          (None, 30, 30, 32)        12832
# _________________________________________________________________
# conv2d_262 (Conv2D)          (None, 15, 15, 32)        9248
# _________________________________________________________________
# conv2d_263 (Conv2D)          (None, 7, 7, 64)          18496
# _________________________________________________________________
# conv2d_264 (Conv2D)          (None, 3, 3, 64)          36928
# _________________________________________________________________
# conv2d_265 (Conv2D)          (None, 2, 2, 128)         73856
# _________________________________________________________________
# conv2d_266 (Conv2D)          (None, 1, 1, 128)         147584
# _________________________________________________________________
# flatten_38 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_75 (Dense)             (None, 512)               66048
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_76 (Dense)             (None, 4)                 2052
# =================================================================
# Total params: 367,844
# Trainable params: 367,844
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
historyBoth = cnnBoth.train()
# Out:
# training model
# Train on 2361 samples, validate on 591 samples
# Epoch 1/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 1.3061 - accuracy: 0.4168 - val_loss: 1.2773 - val_accuracy: 0.4247
#
# Epoch 00001: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 2/50
# 2361/2361 [==============================] - 6s 3ms/step - loss: 1.2298 - accuracy: 0.4435 - val_loss: 1.1697 - val_accuracy: 0.4856
#
# Epoch 00002: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 3/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 1.1056 - accuracy: 0.5142 - val_loss: 1.1530 - val_accuracy: 0.4755
#
# Epoch 00003: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 4/50
# 2361/2361 [==============================] - 6s 3ms/step - loss: 1.0595 - accuracy: 0.5392 - val_loss: 1.0287 - val_accuracy: 0.5770
#
# Epoch 00004: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 5/50
# 2361/2361 [==============================] - 6s 3ms/step - loss: 0.9607 - accuracy: 0.5811 - val_loss: 0.9847 - val_accuracy: 0.6159
#
# Epoch 00005: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 6/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.9104 - accuracy: 0.6129 - val_loss: 0.9136 - val_accuracy: 0.6328
#
# Epoch 00006: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 7/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.8574 - accuracy: 0.6531 - val_loss: 0.9313 - val_accuracy: 0.6311
#
# Epoch 00007: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 8/50
# 2361/2361 [==============================] - 6s 3ms/step - loss: 0.8387 - accuracy: 0.6603 - val_loss: 0.9254 - val_accuracy: 0.6362
#
# Epoch 00008: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 9/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.7969 - accuracy: 0.6806 - val_loss: 0.8654 - val_accuracy: 0.6684
#
# Epoch 00009: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 10/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.7246 - accuracy: 0.7226 - val_loss: 0.8970 - val_accuracy: 0.6717
#
# Epoch 00010: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 11/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.6935 - accuracy: 0.7188 - val_loss: 0.8755 - val_accuracy: 0.6768
#
# Epoch 00011: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 12/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.6549 - accuracy: 0.7391 - val_loss: 0.8539 - val_accuracy: 0.6751
#
# Epoch 00012: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 13/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.5986 - accuracy: 0.7675 - val_loss: 0.8891 - val_accuracy: 0.6650
#
# Epoch 00013: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 14/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.5483 - accuracy: 0.7916 - val_loss: 0.9781 - val_accuracy: 0.6819
#
# Epoch 00014: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 15/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.4756 - accuracy: 0.8183 - val_loss: 0.9473 - val_accuracy: 0.6802
#
# Epoch 00015: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 16/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.4649 - accuracy: 0.8196 - val_loss: 0.9525 - val_accuracy: 0.6751
#
# Epoch 00016: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 17/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.4252 - accuracy: 0.8365 - val_loss: 1.0852 - val_accuracy: 0.6582
#
# Epoch 00017: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 18/50
# 2361/2361 [==============================] - 6s 3ms/step - loss: 0.3541 - accuracy: 0.8679 - val_loss: 1.0535 - val_accuracy: 0.6768
#
# Epoch 00018: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 19/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.2915 - accuracy: 0.8911 - val_loss: 1.1085 - val_accuracy: 0.6937
#
# Epoch 00019: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 20/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.2338 - accuracy: 0.9106 - val_loss: 1.2898 - val_accuracy: 0.6464
#
# Epoch 00020: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 21/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.2299 - accuracy: 0.9195 - val_loss: 1.3288 - val_accuracy: 0.6819
#
# Epoch 00021: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 22/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.1639 - accuracy: 0.9411 - val_loss: 1.5350 - val_accuracy: 0.6176
#
# Epoch 00022: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 23/50
# 2361/2361 [==============================] - 6s 3ms/step - loss: 0.1068 - accuracy: 0.9636 - val_loss: 1.7578 - val_accuracy: 0.6582
#
# Epoch 00023: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 24/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0901 - accuracy: 0.9691 - val_loss: 1.7807 - val_accuracy: 0.6633
#
# Epoch 00024: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 25/50
# 2361/2361 [==============================] - 6s 3ms/step - loss: 0.0860 - accuracy: 0.9704 - val_loss: 1.9388 - val_accuracy: 0.6227
#
# Epoch 00025: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 26/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.1004 - accuracy: 0.9636 - val_loss: 1.8468 - val_accuracy: 0.6328
#
# Epoch 00026: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 27/50
# 2361/2361 [==============================] - 6s 3ms/step - loss: 0.0637 - accuracy: 0.9792 - val_loss: 1.9425 - val_accuracy: 0.6667
#
# Epoch 00027: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 28/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0441 - accuracy: 0.9839 - val_loss: 2.0637 - val_accuracy: 0.6599
#
# Epoch 00028: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 29/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0512 - accuracy: 0.9835 - val_loss: 2.2583 - val_accuracy: 0.6379
#
# Epoch 00029: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 30/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0795 - accuracy: 0.9776 - val_loss: 2.1079 - val_accuracy: 0.6379
#
# Epoch 00030: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 31/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.1041 - accuracy: 0.9644 - val_loss: 1.9617 - val_accuracy: 0.5871
#
# Epoch 00031: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 32/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0613 - accuracy: 0.9797 - val_loss: 1.9736 - val_accuracy: 0.6565
#
# Epoch 00032: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 33/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0378 - accuracy: 0.9886 - val_loss: 2.1310 - val_accuracy: 0.6514
#
# Epoch 00033: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 34/50
# 2361/2361 [==============================] - 6s 3ms/step - loss: 0.0159 - accuracy: 0.9962 - val_loss: 2.4059 - val_accuracy: 0.6836
#
# Epoch 00034: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 35/50
# 2361/2361 [==============================] - 6s 3ms/step - loss: 0.0210 - accuracy: 0.9936 - val_loss: 2.3086 - val_accuracy: 0.6548
#
# Epoch 00035: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 36/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0166 - accuracy: 0.9953 - val_loss: 2.3326 - val_accuracy: 0.6802
#
# Epoch 00036: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 37/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0169 - accuracy: 0.9941 - val_loss: 2.3659 - val_accuracy: 0.6294
#
# Epoch 00037: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 38/50
# 2361/2361 [==============================] - 6s 3ms/step - loss: 0.0211 - accuracy: 0.9928 - val_loss: 2.3555 - val_accuracy: 0.6616
#
# Epoch 00038: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 39/50
# 2361/2361 [==============================] - 6s 3ms/step - loss: 0.0231 - accuracy: 0.9932 - val_loss: 2.2888 - val_accuracy: 0.6430
#
# Epoch 00039: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 40/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0097 - accuracy: 0.9966 - val_loss: 2.5599 - val_accuracy: 0.6565
#
# Epoch 00040: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 41/50
# 2361/2361 [==============================] - 8s 3ms/step - loss: 0.0121 - accuracy: 0.9966 - val_loss: 2.6154 - val_accuracy: 0.6277
#
# Epoch 00041: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 42/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 2.7090 - val_accuracy: 0.6633
#
# Epoch 00042: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 43/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0195 - accuracy: 0.9936 - val_loss: 2.6316 - val_accuracy: 0.6413
#
# Epoch 00043: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 44/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0216 - accuracy: 0.9932 - val_loss: 2.5026 - val_accuracy: 0.6684
#
# Epoch 00044: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 45/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0539 - accuracy: 0.9835 - val_loss: 2.2696 - val_accuracy: 0.6717
#
# Epoch 00045: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 46/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.1133 - accuracy: 0.9653 - val_loss: 1.6946 - val_accuracy: 0.6582
#
# Epoch 00046: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 47/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0583 - accuracy: 0.9792 - val_loss: 1.9202 - val_accuracy: 0.6599
#
# Epoch 00047: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 48/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0201 - accuracy: 0.9928 - val_loss: 2.3329 - val_accuracy: 0.6227
#
# Epoch 00048: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 49/50
# 2361/2361 [==============================] - 7s 3ms/step - loss: 0.0173 - accuracy: 0.9932 - val_loss: 2.4800 - val_accuracy: 0.6599
#
# Epoch 00049: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5
# Epoch 50/50
# 2361/2361 [==============================] - 6s 3ms/step - loss: 0.0160 - accuracy: 0.9941 - val_loss: 2.2796 - val_accuracy: 0.6904
#
# Epoch 00050: saving model to /home/czerwone/Desktop/Projects/Python/EmotionRecognition/Mustaqeem_Saved_Models/keras_cnn_trained_model.h5

# %%
cnnBoth.evaluate()
# Out:
# 591/591 [==============================] - 0s 614us/step
# Test loss: 2.27958295308999
# Test accuracy: 0.6903553009033203
# (591,) (591,)
#               precision    recall  f1-score   support
#
#            0       0.66      0.78      0.72       224
#            1       0.46      0.33      0.38        91
#            2       0.77      0.75      0.76       169
#            3       0.78      0.71      0.75       107
#
#     accuracy                           0.69       591
#    macro avg       0.67      0.64      0.65       591
# weighted avg       0.68      0.69      0.68       591
#
# [[175  17  24   8]
#  [ 42  30  11   8]
#  [ 30   7 127   5]
#  [ 17  11   3  76]]

# %%
cnnBoth.printHistory(historyBoth)

# %%
def getSpectograms(fileList,preEmph = True):
    spectogramList = np.zeros((len(fileList),128,128))
    ind = 0
    for entry in fileList:
        signalData,_ = librosa.load(entry, res_type='kaiser_fast',sr=sampleRate);
        if preEmph:
            pre_emphasis = 0.97
            signalData = np.append(signalData[0], signalData[1:] - pre_emphasis * signalData[:-1])
        hopSize = int(np.ceil(len(signalData)/128))
        spectogram = np.abs(librosa.stft(signalData,n_fft=hopSize*2,hop_length=hopSize)**2)
        spectogram = librosa.power_to_db(spectogram,ref=np.max)
        mel = librosa.filters.mel(sr=sampleRate,n_fft=hopSize*2, n_mels=128)
        melSpectogram = mel.dot(spectogram)
        spectogramList[ind,:,:] = melSpectogram[:,0:128]
        ind = ind+1
    return spectogramList

# %%
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = sorted(os.listdir(dirName))
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)                
    return allFiles

# %%
def getDatasetStats(pathName,IsRavdess = True):
    length = [];
    labels = [0]*8;
    fileList = getListOfFiles(pathName);
    for entry in fileList:
        #Calculate length
        audio = librosa.load(entry,sr=sampleRate)[0];
        length.append(len(librosa.effects.trim(audio)[0]));
    meanLength,minLength,maxLength = np.mean(length),np.min(length),np.max(length);
    
    print(length.index(minLength))
    print(length.index(maxLength))
    return [meanLength,minLength,maxLength];

# %%
def classifyData(fileName,IsRavdess = True,customFileList=None):
    #3 Emotion (1-Neutral 2-Calm 3-Happy 4-Sad 5-Angry 6-Scared 7-Disgust 8-Surprised)
    #4 Emotional Intensity(1-Normal 2-Strong)
    #7 Actor (%2 == 1 Male %2 == 0 Female)
        dataFeature = list();
        if customFileList is None:
            fileList = getListOfFiles(fileName)
        else:
            fileList = customFileList
            
        for entry in fileList:
            dataFeature.append(extractFromFName(entry,IsRavdess));
        return dataFeature;

def extractFromFName(fileName,IsRavdess = True):
    if IsRavdess:
        fileName = fileName.split('/')[-1]; #Choosing the filename only
        fileName = fileName.split('.')[0].split('-'); #Removing .wav then splitting info numbers
        fileName = [int(i) for i in fileName]; #Converting string array into int array
        val = [fileName[2],fileName[3],fileName[6]%2];
    else: #IEMOCAP Dataset Extraction
        fileName = fileName.split('/')[-1].split('.')[0]
        if "impro" in fileName:
            labelFileName= fileName.split('_')[0]+'_'+fileName.split('_')[1]+'.txt'
        else:
            labelFileName= fileName.split('_')[0]+'_'+fileName.split('_')[1]+'_'+fileName.split('_')[2]+'.txt'
        
        with open(iemocapLabelPath+'/'+labelFileName, 'r') as f:
            lines = f.readlines()
            for line in lines:
                if re.search(fileName, line):
                    emotion = line.split('\t')[2]
                    break
        val=emotion        
    return val

def ravdessGetUsedOnlyData(fileList,usedAttributes):
    newFileList =[]
    for file in fileList:
        fileName = file.split('/')[-1]; #Choosing the filename only
        fileName = fileName.split('.')[0].split('-'); #Removing .wav then splitting info numbers
        fileName = [int(i) for i in fileName]; #Converting string array into int array
        if fileName[2] in usedAttributes:
            newFileList.append(file)
    return newFileList

# %%
def iemocapGetUsedAttributes(fileList,Y,usedAttributes):
    iemocapLabels = {'neu':1, 'hap':2, 'sad':3, "ang":4}
    deletedIndexes = []
    dictY =[]
    ind = 0
    for em in Y:
        if em not in usedAttributes:
            deletedIndexes.append(ind)
        ind = ind+1
    
    for index in sorted(deletedIndexes, reverse=True):
        del fileList[index]
        del Y[index]
    
    for emotion in Y:
        dictY.append(iemocapLabels[emotion])
        
    return [fileList,np.array(dictY)]

# %%
def dataNormalization(X):
    mean = np.mean(X, axis=(1,2), keepdims=True);
    std = np.std(X,axis=(1,2),keepdims=True);
    X = (X-mean)/std;
    return X;

# %%
class cnn:
    def __init__(self, labels, features, test_size=0.2, num_classes=8, epochs=50,
                 batch_size=128):  # not sure if ideal // hyperparmeter tuning needed
        self.labels = labels
        self.features = features
        
        self.test_size = test_size
        self.x_train = None
        self.y_train = None
        
        self.x_test = None
        self.y_test = None
        self.model = None
        self.num_classes = num_classes
        self.epochs = epochs
        self.batch_size = batch_size

    def split_train_test(self):
        self.x_train, self.x_test, self.y_train, self.y_test = sklearn.model_selection.train_test_split(
            self.features, self.labels, test_size=self.test_size, random_state=np.random)
        
        
        
        # we need to transform x and turn y into one hot
        #self.x_train = self.x_train[..., np.newaxis] # add new dimension      
        #self.x_test = self.x_test[..., np.newaxis] 
        self.y_train = keras.utils.to_categorical(self.y_train, self.num_classes)
        self.y_test = keras.utils.to_categorical(self.y_test, self.num_classes) 
        
        #Save Variables
        if os.path.exists(os.getcwd()+'/Variables/Mustaqeem/dataVariables_Mustaqeem.pkl') == False:
            if os.path.exists(os.getcwd()+'/Variables/Mustaqeem/') == False: 
                os.makedirs(os.getcwd()+"/Variables/Mustaqeem")
            pickle_out = open("Variables/Huang/dataVariables_Mustaqeem.pkl","wb")
        
        with open('Variables/Huang/dataVariables_Mustaqeem.pkl', 'wb') as f:  # Python 3: open(..., 'wb')
            pickle.dump([self.x_train,self.x_test,self.y_train,self.y_test], f)

    def loadPreviousVariables(self):
        with open('Variables/Huang/dataVariables_Mustaqeem.pkl','rb') as f:  # Python 3: open(..., 'rb')
            self.x_train,self.x_test,self.y_train,self.y_test = pickle.load(f)
        
    def build_model(self):
        layers = keras.layers
        
        self.model = keras.Sequential([
            layers.Conv2D(16, (7, 7),strides=(2,2), padding='same',
                          activation=tf.nn.relu, input_shape=self.x_train.shape[1:]), 
            #layers.BatchNormalization(),
            layers.Conv2D(32, (5, 5),strides=(2,2), activation=tf.nn.relu),
            #layers.BatchNormalization(),
            layers.Conv2D(32, (3, 3),strides=(2,2),padding='same', activation=tf.nn.relu),
            #layers.BatchNormalization(),
            layers.Conv2D(64, (3, 3),strides=(2,2), activation=tf.nn.relu),
            #layers.BatchNormalization(),
            layers.Conv2D(64, (3, 3),strides=(2,2), activation=tf.nn.relu),
            #layers.BatchNormalization(),
            layers.Conv2D(128, (3, 3),strides=(2,2),padding='same', activation=tf.nn.relu),
            #layers.BatchNormalization(),
            layers.Conv2D(128, (3, 3),strides=(2,2),padding='same', activation=tf.nn.relu),
            #layers.BatchNormalization(),
            layers.Flatten(),
            
            layers.Dense(512, activation='relu'),
            layers.Dropout(0.25),
            
            layers.Dense(self.num_classes, activation='softmax'),
        ])
        opt = keras.optimizers.Adam(learning_rate=0.001)
        self.model.compile(loss='categorical_crossentropy',
                           optimizer=opt,
                           metrics=['accuracy'],)
        print("built cnn model..")
        print(self.model.summary())

    def train(self):
        print("training model")
        save_dir = os.path.join(os.getcwd(), 'Mustaqeem_Saved_Models')
        model_name = 'keras_cnn_trained_model.h5'
        if not os.path.isdir(save_dir):
            os.makedirs(save_dir)
        model_path = os.path.join(save_dir, model_name)
        # if os.path.isfile(model_path):
        #     self.model.load_weights(model_path)
        #callback = tf.keras.callbacks.LearningRateScheduler(scheduler)
        checkpoint = ModelCheckpoint(
            model_path, monitor='val_acc', verbose=1, save_best_only=False, mode='max')
        tensorboard = TensorBoard(log_dir="logs/{}".format(time()), write_graph=True,
                                  write_images=True, histogram_freq=0)
        history = self.model.fit(self.x_train, self.y_train,
                  batch_size=self.batch_size,
                  epochs=self.epochs,
                  validation_data=(self.x_test, self.y_test),
                  shuffle=True,
                  callbacks=[tensorboard, checkpoint]
                  #callbacks=[tensorboard, checkpoint,callback]
                                )
        return history
               
    def printHistory(self,history):
        import matplotlib.pyplot as plt
        from matplotlib.pyplot import figure

        figure(figsize=(8, 6), dpi=80)
        acc = history.history['accuracy']
        val_acc = history.history['val_accuracy']
        loss = history.history['loss']
        val_loss = history.history['val_loss']
        
        epochs = range(1, len(acc) + 1)
        plt.plot(epochs, loss, 'r-', label='Eğitim Kaybı')
        plt.plot(epochs, val_loss, 'b-', label='Doğrulama Kaybı')
        plt.title('Eğitim ve Doğrulama Kaybı')
        plt.xlabel('Epok')
        plt.ylabel('Kayıp')
        plt.legend()
        plt.show()

        figure(figsize=(8, 6), dpi=80)
        plt.plot(epochs, acc, 'r-', label='Eğitim Başarımı')
        plt.plot(epochs, val_acc, 'b-', label='Doğrulama Başarımı')
        plt.title('Eğitim ve Doğrulama Başarımı')
        plt.xlabel('Epok')
        plt.ylabel('Başarım')
        plt.legend()
        plt.show()
        

    def evaluate(self):
        scores = self.model.evaluate(self.x_test, self.y_test, verbose=1)
        print('Test loss:', scores[0])
        print('Test accuracy:', scores[1])

        from sklearn.metrics import classification_report
        predictions = self.model.predict_classes(self.x_test)
        # add roc_auc
        y_new = np.argmax(self.y_test, axis=1)
        print(np.shape(predictions), np.shape(y_new))
        report = classification_report(y_new, predictions)
        print(report)

        
        matrix = confusion_matrix(y_new, predictions)
        print (matrix)
        df_cm = pd.DataFrame(matrix, range(self.num_classes),
                  range(self.num_classes))
        # plt.figure(figsize = (10,7))
        sn.set(font_scale=1.4)#for label size
        sn.heatmap(df_cm, annot=True,annot_kws={"size": 12})# font size
        plt.show()
        plt.savefig('confusion_matrix.pdf')
        plt.savefig('confusion_matrix.pgf') # for latex

        
def scheduler(epoch, lr):
    if epoch != 0 and int(epoch)%10==0:
        return lr * tf.math.exp(-0.1)
    else:
        return lr
